# %% [markdown]
# # get instrument filepath

# %%
import yaml
i=0
inst_clas = 'Drums'
tracks_inst_class = []
path = f'babyslakh_16k/babyslakh_16k/Track0000{i+1}/metadata.yaml'
with open(path, 'r') as file:
   data = yaml.safe_load(file)
for key in data['stems'].keys():
    if data['stems'][key]['inst_class'] == inst_clas:
        tracks_inst_class.append(key)

tracks_inst_class
# Out:
# ['S01']

# %%
wav_paths_inst_class = [f'babyslakh_16k/babyslakh_16k/Track0000{i+1}/stems/{track}.wav' for track in tracks_inst_class]

# %%
wav_path = f'babyslakh_16k/babyslakh_16k/Track0000{i+1}/mix.wav'

# %% [markdown]
# # Make a loop for creating images inside the file

# %%
# %load_ext autoreload
# %autoreload 2
from wav_to_spectrogram_utils import wav_to_stft, get_windows
import os, cv2, librosa
import time, yaml
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = (20,15)


start_time = time.time()
inst_clas = 'Drums'

for i in range(20):
    print(i)
    tracks_inst_class = []
    if i < 9:
        path = f'babyslakh_16k/babyslakh_16k/Track0000{i+1}/metadata.yaml'
    else:
        path = f'babyslakh_16k/babyslakh_16k/Track000{i+1}/metadata.yaml'
    with open(path, 'r') as file:
       data = yaml.safe_load(file)
    for key in data['stems'].keys():
        if data['stems'][key]['inst_class'] == inst_clas:
            tracks_inst_class.append(key)
    wav_paths_inst_class = [path[:-13] +f'stems/{track}.wav' for track in tracks_inst_class]
    wav_path = path[:-13]+'mix.wav'
    for path_ in wav_paths_inst_class:
        Intensity_Stft, Angle_Stft, n, sr = wav_to_stft(path_)
        Intensity_Stft = librosa.amplitude_to_db(Intensity_Stft, ref=0)
        Intensity_Stft = Intensity_Stft.astype(np.uint8)
        windows = get_windows(Intensity_Stft, 64, 128)
        print(len(windows),windows[0].shape, n)
        os.makedirs(path_[:-13]+f'Spectrograms/{inst_clas}_windows/', exist_ok=True)
        for k, window in enumerate(windows):
            # print(path_[:-4]+f'_{inst_clas}_windows/{k}.jpg')
            if os.path.isfile(path_[:-13]+f'Spectrograms/{inst_clas}_windows/{k}.jpg'):
                os.remove(path_[:-13]+f'Spectrograms/{inst_clas}_windows/{k}.jpg')
            cv2.imwrite(path_[:-13]+f'Spectrograms/{inst_clas}_windows/{k}.jpg', window)

    Intensity_Stft, Angle_Stft, n, sr = wav_to_stft(wav_path)
    Intensity_Stft = librosa.amplitude_to_db(Intensity_Stft, ref=0)
    windows = get_windows(Intensity_Stft, 64, 128)
    os.makedirs(path[:-13]+f'Spectrograms/mix_windows/', exist_ok=True)
    for k, window in enumerate(windows):
        if os.path.isfile(path[:-13]+f'Spectrograms/mix_windows/{k}.jpg'):
            os.remove(path[:-13]+f'Spectrograms/mix_windows/{k}.jpg')
        cv2.imwrite(path[:-13]+f'Spectrograms/mix_windows/{k}.jpg', window)

    print(len(windows), f'time = {time.time() - start_time}')
    print((time.time() - start_time)/len(windows))
    start_time = time.time()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0
# (512, 20890)
# 325 (512, 128) 5326338
# (512, 20890)
# 325 time = 4.682496070861816
# 0.01441158808194674
# 1
# (512, 16465)
# 256 (512, 128) 4197889
# (512, 16465)
# 256 time = 1.5373790264129639
# 0.006005890667438507
# 2
# (512, 18915)
# 294 (512, 128) 4822785
# (512, 18915)
# 294 time = 1.568830966949463
# 0.005336765529347115
# 3
# (512, 20115)
# 313 (512, 128) 5128705
# (512, 20115)
# 313 time = 5.280939102172852
# 0.016937981779202103
# 4
# (512, 21374)
# 332 (512, 128) 5449730
# (512, 21374)
# 332 time = 4.253346920013428
# 0.012813966676413295
# 5
# (512, 21305)
# 331 (512, 128) 5432065
# (512, 21305)
# 331 time = 2.3997397422790527
# 0.007250721721130555
# 6
# (512, 21349)
# 332 (512, 128) 5443330
# (512, 21349)
# 332 time = 1.635105848312378
# 0.004925480089991926
# 7
# (512, 22452)
# 349 (512, 128) 5724674
# (512, 22452)
# 349 time = 2.368618965148926
# 0.006787323336888179
# 8
# (512, 13892)
# 216 (512, 128) 3541761
# (512, 13892)
# 216 time = 0.964329719543457
# 0.0044655413539321336
# 9
# (512, 15731)
# 244 (512, 128) 4010754
# (512, 15731)
# 244 time = 1.138035774230957
# 0.004664763075406434
# 10
# (512, 17117)
# 266 (512, 128) 4364289
# (512, 17117)
# 266 time = 1.4332799911499023
# 0.005388884616077394
# 11
# (512, 26613)
# 414 (512, 128) 6785793
# (512, 26613)
# 414 time = 5.983782052993774
# 0.014456121241988766
# 12
# (512, 19216)
# 299 (512, 128) 4899329
# (512, 19216)
# 299 time = 1.6219756603240967
# 0.005425327996346464
# 13
# (512, 23711)
# 369 (512, 128) 6045697
# (512, 23711)
# 369 time = 1.8864202499389648
# 0.005112612473609324
# 14
# (512, 21355)
# 332 (512, 128) 5444865
# (512, 21355)
# 332 time = 1.8955810070037842
# 0.005710321736623006
# 15
# (512, 17531)
# 272 (512, 128) 4469762
# (512, 17531)
# 272 time = 1.328503131866455
# 0.004884724231327281
# 16
# (512, 27132)
# 422 (512, 128) 6918145
# (512, 27132)
# 422 time = 7.292868375778198
# 0.01732106683378536
# 17
# (512, 25663)
# 399 (512, 128) 6543361
# (512, 25663)
# 399 time = 4.280972480773926
# 0.010731201721612075
# 18
# (512, 20040)
# 312 (512, 128) 5109505
# (512, 20040)
# 312 time = 2.158087968826294
# 0.006917986350181775
# 19
# (512, 30073)
# 468 (512, 128) 7667969
# (512, 30073)
# 468 time = 5.980876207351685
# 0.01282345280688033

# %% [markdown]
# # création du jeu de donnée

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
for i in range(15):
    if i < 9:
        directory = f'babyslakh_16k/babyslakh_16k/Track0000{i+1}/Spectrograms/'
    else:
        directory = f'babyslakh_16k/babyslakh_16k/Track000{i+1}/Spectrograms/'
    if i == 0:
        all_dataset_X = keras.preprocessing.image_dataset_from_directory(directory+'mix_windows/',
                                                                        labels=None,
                                                                        color_mode= "grayscale",
                                                                        image_size=(512, 128), shuffle = False, batch_size = 8)
        all_dataset_y = keras.preprocessing.image_dataset_from_directory(directory+'Drums_windows/',
                                                                    labels=None,
                                                                    color_mode= "grayscale",
                                                                    image_size=(512, 128), shuffle = False, batch_size = 8)
    else:
        all_dataset_X = all_dataset_X.concatenate(keras.preprocessing.image_dataset_from_directory(directory+'mix_windows/',
                                                                                                        labels=None,
                                                                                                        color_mode= "grayscale",
                                                                                                        image_size=(512, 128), shuffle = False, batch_size = 8))
        all_dataset_y = all_dataset_y.concatenate(keras.preprocessing.image_dataset_from_directory(directory+'Drums_windows/',
                                                                    labels=None,
                                                                    color_mode= "grayscale",
                                                                    image_size=(512, 128), shuffle = False, batch_size = 8))

count = 0
nbr_imgs = 10
for image_mix, image_drum in zip(all_dataset_X,all_dataset_y):
    if count == nbr_imgs:
        break
    plt.subplot(1,2,1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(image_mix[0].numpy())
    plt.xlabel('mix')


    plt.subplot(1,2,2)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(image_drum[0].numpy())
    plt.xlabel('drum')

    plt.show()
    count+=1
# Out:
# 2024-02-26 02:27:26.470947: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-26 02:27:26.646392: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 02:27:26.646533: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 02:27:26.656880: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 02:27:26.745517: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-26 02:27:28.132298: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found 0 files belonging to 1 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 10
#       8     directory = f'babyslakh_16k/babyslakh_16k/Track000{i+1}/Spectrograms/'
#       9 if i == 0:
# ---> 10     all_dataset_X = keras.preprocessing.image_dataset_from_directory(directory+'mix_windows/',
#      11                                                                     labels=None,
#      12                                                                     color_mode= "grayscale",
#      13                                                                     image_size=(512, 128), shuffle = False, batch_size = 8)
#      14     all_dataset_y = keras.preprocessing.image_dataset_from_directory(directory+'Drums_windows/',
#      15                                                                 labels=None,
#      16                                                                 color_mode= "grayscale",
#      17                                                                 image_size=(512, 128), shuffle = False, batch_size = 8)
#      18 else:
#
# File ~/.pyenv/versions/3.10.6/envs/Music_Seg/lib/python3.10/site-packages/keras/src/utils/image_dataset.py:303, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, **kwargs)
#     299 image_paths, labels = dataset_utils.get_training_or_validation_split(
#     300     image_paths, labels, validation_split, subset
#     301 )
#     302 if not image_paths:
# --> 303     raise ValueError(
#     304         f"No images found in directory {directory}. "
#     305         f"Allowed formats: {ALLOWLIST_FORMATS}"
#     306     )
#     308 dataset = paths_and_labels_to_dataset(
#     309     image_paths=image_paths,
#     310     image_size=image_size,
#    (...)
#     316     crop_to_aspect_ratio=crop_to_aspect_ratio,
#     317 )
#     319 if batch_size is not None:
#
# ValueError: No images found in directory babyslakh_16k/babyslakh_16k/Track00001/Spectrograms/mix_windows/. Allowed formats: ('.bmp', '.gif', '.jpeg', '.jpg', '.png')

# %%
DATASET_SIZE = all_dataset_X.cardinality().numpy()
train_size = int(0.7 * DATASET_SIZE)
val_size = int(0.15 * DATASET_SIZE)

train_ds_X = all_dataset_X.take(train_size)
val_ds_X = all_dataset_X.skip(train_size).take(val_size)
train_ds_y = all_dataset_y.take(train_size)
val_ds_y = all_dataset_y.skip(train_size).take(val_size)

train_ds_X, train_ds_y = train_ds_X.shuffle(buffer_size=2, seed=2), train_ds_y.shuffle(buffer_size=2, seed=2)
X = tf.data.Dataset.zip((train_ds_X, train_ds_y))
X_val = tf.data.Dataset.zip((val_ds_X, val_ds_y))

# %% [markdown]
# # Entrainnement

# %%
# %load_ext autoreload
# %autoreload 2
from Unet_Model import build_unet_model

unet_model = build_unet_model()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 4194304 bytes after encountering the first element of size 4194304 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-01-24 19:16:14.006736: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 2097152 bytes after encountering the first element of size 2097152 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-01-24 19:16:14.012743: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 2097152 bytes after encountering the first element of size 2097152 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 413/413 - 11s - loss: 2.7646 - val_loss: 3.6864 - 11s/epoch - 27ms/step

# %%
unet_model.save('unet.keras')

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
unet_model = keras.models.load_model('unet.keras')
# Out:
# 2024-01-24 23:14:17.954441: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-24 23:14:18.339577: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-24 23:14:18.339618: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-24 23:14:18.400033: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-24 23:14:18.530049: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-24 23:14:19.715251: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-01-24 23:14:21.797158: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-24 23:14:22.043011: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-24 23:14:22.043220: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-24 23:14:22.046709: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-24 23:14:22.046793: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-24 23:14:22.046828: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-24 23:14:22.311970: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-24 23:14:22.312032: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-24 23:14:22.312050: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-01-24 23:14:22.312092: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-24 23:14:22.312173: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3600 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # test inference

# %%
directory = f'babyslakh_16k/babyslakh_16k/Track000{16}/'
# test_X = keras.preprocessing.image_dataset_from_directory(directory+'mix_windows/',
#                                                                 labels=None,
#                                                                 color_mode= "grayscale",
#                                                         image_size=(128, 512), shuffle = False, batch_size = 1)

path = directory + 'metadata.yaml'
wav_path = directory+'mix.wav'

Intensity_Stft, Angle_Stft, n, sr = wav_to_stft(wav_path)
Intensity_Stft = librosa.amplitude_to_db(Intensity_Stft, ref=0)
windows = get_windows(Intensity_Stft, 64, 128)
test_X = np.array(windows)
test_X.shape
# Out:
# (272, 512, 128)

# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
import matplotlib.pyplot as plt
import os, cv2, librosa, numpy as np
from wav_to_spectrogram_utils import wav_to_stft, get_windows, get_Stft_from_windows, sft_to_signal, sft_to_wav
import time, yaml

for i in range(15,20):
    if i < 9:
        directory = f'babyslakh_16k/babyslakh_16k/Track0000{i+1}/'
    else:
        directory = f'babyslakh_16k/babyslakh_16k/Track000{i+1}/'
    wav_path = directory+'mix.wav'

    Intensity_Stft, Angle_Stft, n, sr = wav_to_stft(wav_path)
    Intensity_Stft = librosa.amplitude_to_db(Intensity_Stft, ref=0)
    windows = get_windows(Intensity_Stft, 64, 128)
    windows = [np.reshape(window, (1,512,128,1)) for window in windows]
    test_X = tf.data.Dataset.from_tensor_slices(windows)
    y_test = unet_model.predict(test_X)
    windows_res = [ np.reshape(y_test[k],(512,128)) for k in range(y_test.shape[0])]
    Intensity_Stft_res = get_Stft_from_windows(windows_res, 64, 128)
    print(min(Intensity_Stft_res), max(Intensity_Stft_res), Intensity_Stft_res.shape)
    break
    diff_shape = Angle_Stft.shape[1] - Intensity_Stft_res.shape[1]
    Intensity_Stft_res = librosa.db_to_amplitude(np.pad(Intensity_Stft_res, ((0, 0), (diff_shape//2, diff_shape//2 + diff_shape%2)), 'constant', constant_values=0), ref=0)
    y_hat = sft_to_signal(Intensity_Stft_res, Angle_Stft, n, sr)
    # sft_to_wav(directory+'predicted_batt.wav',Intensity_Stft_res, Angle_Stft, n, sr)
    plt.plot(y_hat)
    plt.show()
# Out:
# (512, 17531)
# 2024-01-24 23:14:47.346801: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8905
# 272/272 [==============================] - 4s 4ms/step

# %%
# Out:
# 0 (512, 256)
# 1 (256, 128)
# 2 (128, 64)
# 3 (64, 32)
# 4 (32, 16)
# 5 (16, 1)
